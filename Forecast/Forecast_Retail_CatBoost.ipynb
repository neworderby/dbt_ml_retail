# %% [markdown]
# # Retail Sales (Istanbul malls). Revenue predict with CatBoost Regressor

# %% [markdown]
# https://www.kaggle.com/datasets/mehmettahiraslan/customer-shopping-dataset

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import warnings
import keyring
import requests
from dateutil.relativedelta import relativedelta
import os
import numpy as np
import datetime
import matplotlib.pyplot as plt
from datetime import date, timedelta
warnings.filterwarnings("ignore")
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score, accuracy_score, precision_score, f1_score, roc_auc_score, mean_squared_error
import seaborn as sns

# %% [markdown]
# ## Load data

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('/workspaces/dbt_ml_retail/Forecast/customer_shopping_data.csv')

# %% [markdown]
# https://drive.google.com/file/d/1syhtZtr0n57iHuc2MYDrorM_ihu5AqRz/view?usp=drive_link

# %%
# !gdown 1syhtZtr0n57iHuc2MYDrorM_ihu5AqRz #Other way to download from gdrive
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1syhtZtr0n57iHuc2MYDrorM_ihu5AqRz
# To: /content/customer_shopping_data.csv
# 100% 7.54M/7.54M [00:00<00:00, 37.0MB/s]

# %%
df = pd.read_csv('/content/customer_shopping_data.csv')

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5 1500.400
# 1        I317333     C111565    Male   21            Shoes         3 1800.510
# 2        I127801     C266599    Male   20         Clothing         1  300.080
# 3        I173702     C988172  Female   66            Shoes         5 3000.850
# 4        I337046     C189076  Female   53            Books         4   60.600
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5   58.650
# 99453    I325143     C569580    Male   27  Food & Beverage         2   10.460
# 99454    I824010     C103292    Male   63  Food & Beverage         2   10.460
# 99455    I702964     C800631    Male   56       Technology         4 4200.000
# 99456    I232867     C273973  Female   36         Souvenir         3   35.190
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Key metric - Revenue

# %%
df['revenue'] = df['quantity']*df['price']

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5 1500.400
# 1        I317333     C111565    Male   21            Shoes         3 1800.510
# 2        I127801     C266599    Male   20         Clothing         1  300.080
# 3        I173702     C988172  Female   66            Shoes         5 3000.850
# 4        I337046     C189076  Female   53            Books         4   60.600
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5   58.650
# 99453    I325143     C569580    Male   27  Food & Beverage         2   10.460
# 99454    I824010     C103292    Male   63  Food & Beverage         2   10.460
# 99455    I702964     C800631    Male   56       Technology         4 4200.000
# 99456    I232867     C273973  Female   36         Souvenir         3   35.190
#
#       payment_method invoice_date     shopping_mall   revenue
# 0        Credit Card     5/8/2022            Kanyon  7502.000
# 1         Debit Card   12/12/2021    Forum Istanbul  5401.530
# 2               Cash    9/11/2021         Metrocity   300.080
# 3        Credit Card   16/05/2021      Metropol AVM 15004.250
# 4               Cash   24/10/2021            Kanyon   242.400
# ...              ...          ...               ...       ...
# 99452    Credit Card   21/09/2022            Kanyon   293.250
# 99453           Cash   22/09/2021    Forum Istanbul    20.920
# 99454     Debit Card   28/03/2021         Metrocity    20.920
# 99455           Cash   16/03/2021      Istinye Park 16800.000
# 99456    Credit Card   15/10/2022  Mall of Istanbul   105.570
#
# [99457 rows x 11 columns]

# %% [markdown]
# ## EDA

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['color: green' if cell else '' for cell in is_max]

# %%
df['invoice_date'].max()
# Out:
# '9/9/2022'

# %%
df['invoice_date'].min()
# Out:
# '1/1/2021'

# %%
df_gender = df.groupby('gender')['revenue'].agg(['count','mean','sum'])
df_gender[['count','mean','sum']].style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_325ac_row0_col0, #T_325ac_row0_col2, #T_325ac_row1_col1 {
#   color: green;
# }
# </style>
# <table id="T_325ac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_325ac_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_325ac_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_325ac_level0_col2" class="col_heading level0 col2" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_325ac_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_325ac_row0_col0" class="data row0 col0" >59482</td>
#       <td id="T_325ac_row0_col1" class="data row0 col1" >2525.253623</td>
#       <td id="T_325ac_row0_col2" class="data row0 col2" >150207136.020000</td>
#     </tr>
#     <tr>
#       <th id="T_325ac_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_325ac_row1_col0" class="data row1 col0" >39975</td>
#       <td id="T_325ac_row1_col1" class="data row1 col1" >2534.050237</td>
#       <td id="T_325ac_row1_col2" class="data row1 col2" >101298658.230000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Women predominate in the frame

# %%
df_payment_method = df.groupby('payment_method')['revenue'].agg(['count','mean','sum'])
df_payment_method[['count','mean','sum']].style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_ab073_row0_col0, #T_ab073_row0_col1, #T_ab073_row0_col2 {
#   color: green;
# }
# </style>
# <table id="T_ab073" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab073_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ab073_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ab073_level0_col2" class="col_heading level0 col2" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >payment_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab073_level0_row0" class="row_heading level0 row0" >Cash</th>
#       <td id="T_ab073_row0_col0" class="data row0 col0" >44447</td>
#       <td id="T_ab073_row0_col1" class="data row0 col1" >2538.579500</td>
#       <td id="T_ab073_row0_col2" class="data row0 col2" >112832243.020000</td>
#     </tr>
#     <tr>
#       <th id="T_ab073_level0_row1" class="row_heading level0 row1" >Credit Card</th>
#       <td id="T_ab073_row1_col0" class="data row1 col0" >34931</td>
#       <td id="T_ab073_row1_col1" class="data row1 col1" >2521.460129</td>
#       <td id="T_ab073_row1_col2" class="data row1 col2" >88077123.770000</td>
#     </tr>
#     <tr>
#       <th id="T_ab073_level0_row2" class="row_heading level0 row2" >Debit Card</th>
#       <td id="T_ab073_row2_col0" class="data row2 col0" >20079</td>
#       <td id="T_ab073_row2_col1" class="data row2 col1" >2519.867895</td>
#       <td id="T_ab073_row2_col2" class="data row2 col2" >50596427.460000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Cash is used more for purchases

# %%
df_category = df.groupby('category')['revenue'].agg(['count','mean','sum'])
df_category[['count','mean','sum']].style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_2f986_row1_col0, #T_2f986_row1_col2, #T_2f986_row6_col1 {
#   color: green;
# }
# </style>
# <table id="T_2f986" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f986_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2f986_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2f986_level0_col2" class="col_heading level0 col2" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f986_level0_row0" class="row_heading level0 row0" >Books</th>
#       <td id="T_2f986_row0_col0" class="data row0 col0" >4981</td>
#       <td id="T_2f986_row0_col1" class="data row0 col1" >167.547260</td>
#       <td id="T_2f986_row0_col2" class="data row0 col2" >834552.900000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row1" class="row_heading level0 row1" >Clothing</th>
#       <td id="T_2f986_row1_col0" class="data row1 col0" >34487</td>
#       <td id="T_2f986_row1_col1" class="data row1 col1" >3305.500364</td>
#       <td id="T_2f986_row1_col2" class="data row1 col2" >113996791.040000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row2" class="row_heading level0 row2" >Cosmetics</th>
#       <td id="T_2f986_row2_col0" class="data row2 col0" >15097</td>
#       <td id="T_2f986_row2_col1" class="data row2 col1" >449.947864</td>
#       <td id="T_2f986_row2_col2" class="data row2 col2" >6792862.900000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row3" class="row_heading level0 row3" >Food & Beverage</th>
#       <td id="T_2f986_row3_col0" class="data row3 col0" >14776</td>
#       <td id="T_2f986_row3_col1" class="data row3 col1" >57.494251</td>
#       <td id="T_2f986_row3_col2" class="data row3 col2" >849535.050000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row4" class="row_heading level0 row4" >Shoes</th>
#       <td id="T_2f986_row4_col0" class="data row4 col0" >10034</td>
#       <td id="T_2f986_row4_col1" class="data row4 col1" >6632.793649</td>
#       <td id="T_2f986_row4_col2" class="data row4 col2" >66553451.470000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row5" class="row_heading level0 row5" >Souvenir</th>
#       <td id="T_2f986_row5_col0" class="data row5 col0" >4999</td>
#       <td id="T_2f986_row5_col1" class="data row5 col1" >127.190368</td>
#       <td id="T_2f986_row5_col2" class="data row5 col2" >635824.650000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row6" class="row_heading level0 row6" >Technology</th>
#       <td id="T_2f986_row6_col0" class="data row6 col0" >4996</td>
#       <td id="T_2f986_row6_col1" class="data row6 col1" >11581.735388</td>
#       <td id="T_2f986_row6_col2" class="data row6 col2" >57862350.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f986_level0_row7" class="row_heading level0 row7" >Toys</th>
#       <td id="T_2f986_row7_col0" class="data row7 col0" >10087</td>
#       <td id="T_2f986_row7_col1" class="data row7 col1" >394.609521</td>
#       <td id="T_2f986_row7_col2" class="data row7 col2" >3980426.240000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Clothing, shoes & technology are most popular categories per revenue

# %%
df['age'].min()
# Out:
# 18

# %%
df['age'].max()
# Out:
# 69

# %% [markdown]
# Bins of age group:

# %%
df['age_group'] = pd.cut(df['age'],[15,20,25,30,35,40,45,50,55,60,65,np.inf])

# %%
df_age_group = df.groupby('age_group')['revenue'].agg(['count','mean','sum'])
df_age_group[['count','mean','sum']].style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_df668_row4_col0, #T_df668_row4_col2, #T_df668_row5_col1 {
#   color: green;
# }
# </style>
# <table id="T_df668" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df668_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_df668_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_df668_level0_col2" class="col_heading level0 col2" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df668_level0_row0" class="row_heading level0 row0" >(15.0, 20.0]</th>
#       <td id="T_df668_row0_col0" class="data row0 col0" >5624</td>
#       <td id="T_df668_row0_col1" class="data row0 col1" >2428.677585</td>
#       <td id="T_df668_row0_col2" class="data row0 col2" >13658882.740000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row1" class="row_heading level0 row1" >(20.0, 25.0]</th>
#       <td id="T_df668_row1_col0" class="data row1 col0" >9735</td>
#       <td id="T_df668_row1_col1" class="data row1 col1" >2512.520658</td>
#       <td id="T_df668_row1_col2" class="data row1 col2" >24459388.610000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row2" class="row_heading level0 row2" >(25.0, 30.0]</th>
#       <td id="T_df668_row2_col0" class="data row2 col0" >9665</td>
#       <td id="T_df668_row2_col1" class="data row2 col1" >2579.320306</td>
#       <td id="T_df668_row2_col2" class="data row2 col2" >24929130.760000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row3" class="row_heading level0 row3" >(30.0, 35.0]</th>
#       <td id="T_df668_row3_col0" class="data row3 col0" >9394</td>
#       <td id="T_df668_row3_col1" class="data row3 col1" >2443.105048</td>
#       <td id="T_df668_row3_col2" class="data row3 col2" >22950528.820000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row4" class="row_heading level0 row4" >(35.0, 40.0]</th>
#       <td id="T_df668_row4_col0" class="data row4 col0" >9872</td>
#       <td id="T_df668_row4_col1" class="data row4 col1" >2574.947782</td>
#       <td id="T_df668_row4_col2" class="data row4 col2" >25419884.500000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row5" class="row_heading level0 row5" >(40.0, 45.0]</th>
#       <td id="T_df668_row5_col0" class="data row5 col0" >9564</td>
#       <td id="T_df668_row5_col1" class="data row5 col1" >2589.329913</td>
#       <td id="T_df668_row5_col2" class="data row5 col2" >24764351.290000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row6" class="row_heading level0 row6" >(45.0, 50.0]</th>
#       <td id="T_df668_row6_col0" class="data row6 col0" >9502</td>
#       <td id="T_df668_row6_col1" class="data row6 col1" >2527.414785</td>
#       <td id="T_df668_row6_col2" class="data row6 col2" >24015495.290000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row7" class="row_heading level0 row7" >(50.0, 55.0]</th>
#       <td id="T_df668_row7_col0" class="data row7 col0" >9514</td>
#       <td id="T_df668_row7_col1" class="data row7 col1" >2544.066360</td>
#       <td id="T_df668_row7_col2" class="data row7 col2" >24204247.350000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row8" class="row_heading level0 row8" >(55.0, 60.0]</th>
#       <td id="T_df668_row8_col0" class="data row8 col0" >9418</td>
#       <td id="T_df668_row8_col1" class="data row8 col1" >2504.185096</td>
#       <td id="T_df668_row8_col2" class="data row8 col2" >23584415.230000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row9" class="row_heading level0 row9" >(60.0, 65.0]</th>
#       <td id="T_df668_row9_col0" class="data row9 col0" >9598</td>
#       <td id="T_df668_row9_col1" class="data row9 col1" >2532.673009</td>
#       <td id="T_df668_row9_col2" class="data row9 col2" >24308595.540000</td>
#     </tr>
#     <tr>
#       <th id="T_df668_level0_row10" class="row_heading level0 row10" >(65.0, inf]</th>
#       <td id="T_df668_row10_col0" class="data row10 col0" >7571</td>
#       <td id="T_df668_row10_col1" class="data row10 col1" >2537.428889</td>
#       <td id="T_df668_row10_col2" class="data row10 col2" >19210874.120000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Age group between 15 and 20/ 65+ is the least active.
# * The sample is balanced by age.
# * Age group between 35 and 45 is the aim for us.

# %%
df_shopping_mall = df.groupby('shopping_mall')['revenue'].agg(['count','mean','sum'])
df_shopping_mall[['count','mean','sum']].style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_1258c_row1_col1, #T_1258c_row5_col0, #T_1258c_row5_col2 {
#   color: green;
# }
# </style>
# <table id="T_1258c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1258c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_1258c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1258c_level0_col2" class="col_heading level0 col2" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shopping_mall</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1258c_level0_row0" class="row_heading level0 row0" >Cevahir AVM</th>
#       <td id="T_1258c_row0_col0" class="data row0 col0" >4991</td>
#       <td id="T_1258c_row0_col1" class="data row0 col1" >2533.588099</td>
#       <td id="T_1258c_row0_col2" class="data row0 col2" >12645138.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row1" class="row_heading level0 row1" >Emaar Square Mall</th>
#       <td id="T_1258c_row1_col0" class="data row1 col0" >4811</td>
#       <td id="T_1258c_row1_col1" class="data row1 col1" >2578.694718</td>
#       <td id="T_1258c_row1_col2" class="data row1 col2" >12406100.290000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row2" class="row_heading level0 row2" >Forum Istanbul</th>
#       <td id="T_1258c_row2_col0" class="data row2 col0" >4947</td>
#       <td id="T_1258c_row2_col1" class="data row2 col1" >2487.148017</td>
#       <td id="T_1258c_row2_col2" class="data row2 col2" >12303921.240000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row3" class="row_heading level0 row3" >Istinye Park</th>
#       <td id="T_1258c_row3_col0" class="data row3 col0" >9781</td>
#       <td id="T_1258c_row3_col1" class="data row3 col1" >2517.005181</td>
#       <td id="T_1258c_row3_col2" class="data row3 col2" >24618827.680000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row4" class="row_heading level0 row4" >Kanyon</th>
#       <td id="T_1258c_row4_col0" class="data row4 col0" >19823</td>
#       <td id="T_1258c_row4_col1" class="data row4 col1" >2550.281547</td>
#       <td id="T_1258c_row4_col2" class="data row4 col2" >50554231.100000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row5" class="row_heading level0 row5" >Mall of Istanbul</th>
#       <td id="T_1258c_row5_col0" class="data row5 col0" >19943</td>
#       <td id="T_1258c_row5_col1" class="data row5 col1" >2550.894132</td>
#       <td id="T_1258c_row5_col2" class="data row5 col2" >50872481.680000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row6" class="row_heading level0 row6" >Metrocity</th>
#       <td id="T_1258c_row6_col0" class="data row6 col0" >15011</td>
#       <td id="T_1258c_row6_col1" class="data row6 col1" >2485.030133</td>
#       <td id="T_1258c_row6_col2" class="data row6 col2" >37302787.330000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row7" class="row_heading level0 row7" >Metropol AVM</th>
#       <td id="T_1258c_row7_col0" class="data row7 col0" >10161</td>
#       <td id="T_1258c_row7_col1" class="data row7 col1" >2497.777108</td>
#       <td id="T_1258c_row7_col2" class="data row7 col2" >25379913.190000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row8" class="row_heading level0 row8" >Viaport Outlet</th>
#       <td id="T_1258c_row8_col0" class="data row8 col0" >4914</td>
#       <td id="T_1258c_row8_col1" class="data row8 col1" >2548.095181</td>
#       <td id="T_1258c_row8_col2" class="data row8 col2" >12521339.720000</td>
#     </tr>
#     <tr>
#       <th id="T_1258c_level0_row9" class="row_heading level0 row9" >Zorlu Center</th>
#       <td id="T_1258c_row9_col0" class="data row9 col0" >5075</td>
#       <td id="T_1258c_row9_col1" class="data row9 col1" >2542.079570</td>
#       <td id="T_1258c_row9_col2" class="data row9 col2" >12901053.820000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The most popular mall is Mall of Istanbul

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Lets create features for our model

# %%
start_forecast = "2023-03-08"
end_forecast = "2023-12-31"

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall', 'revenue',
#        'age_group'],
#       dtype='object')

# %%
df_model = df[['gender'#,'age'
,'age_group','category','payment_method','invoice_date','shopping_mall','revenue']]
df_model.head()
# Out:
#    gender     age_group  category payment_method invoice_date   shopping_mall  \
# 0  Female  (25.0, 30.0]  Clothing    Credit Card   2022-08-05          Kanyon
# 1    Male  (20.0, 25.0]     Shoes     Debit Card   2021-12-12  Forum Istanbul
# 2    Male  (15.0, 20.0]  Clothing           Cash   2021-11-09       Metrocity
# 3  Female   (65.0, inf]     Shoes    Credit Card   2021-05-16    Metropol AVM
# 4  Female  (50.0, 55.0]     Books           Cash   2021-10-24          Kanyon
#
#     revenue
# 0  7502.000
# 1  5401.530
# 2   300.080
# 3 15004.250
# 4   242.400

# %%
 df_model['invoice_date'] = pd.to_datetime(df_model['invoice_date'], format='%d/%m/%Y')

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          99457 non-null  object
#  1   age_group       99457 non-null  category
#  2   category        99457 non-null  object
#  3   payment_method  99457 non-null  object
#  4   invoice_date    99457 non-null  datetime64[ns]
#  5   shopping_mall   99457 non-null  object
#  6   revenue         99457 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(1), object(4)
# memory usage: 4.6+ MB

# %%
df_model.head()
# Out:
#    gender     age_group  category payment_method invoice_date   shopping_mall  \
# 0  Female  (25.0, 30.0]  Clothing    Credit Card   2022-08-05          Kanyon
# 1    Male  (20.0, 25.0]     Shoes     Debit Card   2021-12-12  Forum Istanbul
# 2    Male  (15.0, 20.0]  Clothing           Cash   2021-11-09       Metrocity
# 3  Female   (65.0, inf]     Shoes    Credit Card   2021-05-16    Metropol AVM
# 4  Female  (50.0, 55.0]     Books           Cash   2021-10-24          Kanyon
#
#     revenue
# 0  7502.000
# 1  5401.530
# 2   300.080
# 3 15004.250
# 4   242.400

# %%
df_model.sort_values(by='invoice_date',ascending=True)
# Out:
#        gender     age_group         category payment_method invoice_date  \
# 36199  Female   (65.0, inf]  Food & Beverage    Credit Card   2021-01-01
# 78539  Female  (40.0, 45.0]         Clothing    Credit Card   2021-01-01
# 27812    Male  (50.0, 55.0]         Clothing           Cash   2021-01-01
# 27856    Male  (55.0, 60.0]  Food & Beverage    Credit Card   2021-01-01
# 5323     Male  (30.0, 35.0]         Clothing           Cash   2021-01-01
# ...       ...           ...              ...            ...          ...
# 20863  Female   (65.0, inf]         Clothing           Cash   2023-03-08
# 20879  Female  (35.0, 40.0]  Food & Beverage           Cash   2023-03-08
# 61644  Female  (55.0, 60.0]        Cosmetics    Credit Card   2023-03-08
# 27871  Female  (45.0, 50.0]            Shoes    Credit Card   2023-03-08
# 60463  Female  (45.0, 50.0]        Cosmetics           Cash   2023-03-08
#
#           shopping_mall  revenue
# 36199         Metrocity  130.750
# 78539  Mall of Istanbul 4801.280
# 27812         Metrocity 2700.720
# 27856  Mall of Istanbul   83.680
# 5323       Istinye Park  300.080
# ...                 ...      ...
# 20863  Mall of Istanbul 7502.000
# 20879            Kanyon   47.070
# 61644            Kanyon 1016.500
# 27871         Metrocity 5401.530
# 60463            Kanyon   40.660
#
# [99457 rows x 7 columns]

# %%
df_model.columns
# Out:
# Index(['gender', 'age_group', 'category', 'payment_method', 'invoice_date',
#        'shopping_mall', 'revenue'],
#       dtype='object')

# %%
gender = pd.DataFrame({"gender": df_model.gender.drop_duplicates()})
age_group = pd.DataFrame({"age_group": df_model.age_group.drop_duplicates()})
category = pd.DataFrame({"category": df_model.category.drop_duplicates()})
payment_method = pd.DataFrame({"payment_method": df_model.payment_method.drop_duplicates()})
shopping_mall = pd.DataFrame({"shopping_mall": df_model.shopping_mall.drop_duplicates()})
dates = pd.DataFrame({"invoice_date": pd.date_range(start=min(df_model.invoice_date), end=end_forecast, freq="D")})

gender["key"], age_group ["key"], dates["key"], category["key"], payment_method["key"], shopping_mall["key"] = 0, 0, 0, 0, 0, 0

df_all = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(gender, age_group , on="key"), dates, on="key"), category, on="key"), payment_method, on="key"), shopping_mall, on="key")
df_all = df_all.drop("key", axis=1)

df = pd.merge(df_all, df_model, on=["gender", "age_group", "category", "payment_method", "shopping_mall", "invoice_date"], how="left")
df["revenue"] = np.where(df["revenue"].isnull(), 0, df["revenue"])

df["year"] = df["invoice_date"].dt.year
df["day"] = df['invoice_date'].dt.day
df["month"] = df["invoice_date"].dt.month
df["weekday"] = df["invoice_date"].dt.weekday
df["weeknumber"] = df["invoice_date"].dt.weekofyear

df["is1jan"] = np.where((df["month"] == 1) & (df["invoice_date"].dt.day == 1), 1, 0)
df["wn"] = np.where(df["weekday"] <= 4, 1, 0)
df
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 0        Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card
# 1        Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card
# 2        Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card
# 3        Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card
# 4        Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card
# ...         ...           ...          ...       ...            ...
# 5784352    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784353    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784354    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784355    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784356    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
#
#              shopping_mall  revenue  year  day  month  weekday  weeknumber  \
# 0                   Kanyon    0.000  2021    1      1        4          53
# 1           Forum Istanbul    0.000  2021    1      1        4          53
# 2                Metrocity    0.000  2021    1      1        4          53
# 3             Metropol AVM    0.000  2021    1      1        4          53
# 4             Istinye Park    0.000  2021    1      1        4          53
# ...                    ...      ...   ...  ...    ...      ...         ...
# 5784352   Mall of Istanbul    0.000  2023   31     12        6          52
# 5784353  Emaar Square Mall    0.000  2023   31     12        6          52
# 5784354        Cevahir AVM    0.000  2023   31     12        6          52
# 5784355     Viaport Outlet    0.000  2023   31     12        6          52
# 5784356       Zorlu Center    0.000  2023   31     12        6          52
#
#          is1jan  wn
# 0             1   1
# 1             1   1
# 2             1   1
# 3             1   1
# 4             1   1
# ...         ...  ..
# 5784352       0   0
# 5784353       0   0
# 5784354       0   0
# 5784355       0   0
# 5784356       0   0
#
# [5784357 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['gender_ohe']=le.fit_transform(df['gender']).astype('str')
df['category_ohe']=le.fit_transform(df['category']).astype('str')
df['payment_method_ohe']=le.fit_transform(df['payment_method']).astype('str')
df['shopping_mall_ohe']=le.fit_transform(df['shopping_mall']).astype('str')
df['age_group_ohe']=le.fit_transform(df['age_group']).astype('str')

# %%
df.head()
# Out:
#    gender     age_group invoice_date  category payment_method   shopping_mall  \
# 0  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card          Kanyon
# 1  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card  Forum Istanbul
# 2  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card       Metrocity
# 3  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card    Metropol AVM
# 4  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card    Istinye Park
#
#    revenue  year  day  month  weekday  weeknumber  is1jan  wn gender_ohe  \
# 0    0.000  2021    1      1        4          53       1   1          0
# 1    0.000  2021    1      1        4          53       1   1          0
# 2    0.000  2021    1      1        4          53       1   1          0
# 3    0.000  2021    1      1        4          53       1   1          0
# 4    0.000  2021    1      1        4          53       1   1          0
#
#   category_ohe payment_method_ohe shopping_mall_ohe age_group_ohe
# 0            1                  1                 4             2
# 1            1                  1                 2             2
# 2            1                  1                 6             2
# 3            1                  1                 7             2
# 4            1                  1                 3             2

# %%
features_base_model = ["gender_ohe", "age_group_ohe", "category_ohe","payment_method_ohe","shopping_mall_ohe", "day","month","weekday","is1jan","wn"]

# %% [markdown]
# ## Revenue forecast

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
from catboost import CatBoostRegressor

# %%
df.head()
# Out:
#    gender     age_group invoice_date  category payment_method   shopping_mall  \
# 0  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card          Kanyon
# 1  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card  Forum Istanbul
# 2  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card       Metrocity
# 3  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card    Metropol AVM
# 4  Female  (25.0, 30.0]   2021-01-01  Clothing    Credit Card    Istinye Park
#
#    revenue  year  day  month  weekday  weeknumber  is1jan  wn gender_ohe  \
# 0    0.000  2021    1      1        4          53       1   1          0
# 1    0.000  2021    1      1        4          53       1   1          0
# 2    0.000  2021    1      1        4          53       1   1          0
# 3    0.000  2021    1      1        4          53       1   1          0
# 4    0.000  2021    1      1        4          53       1   1          0
#
#   category_ohe payment_method_ohe shopping_mall_ohe age_group_ohe
# 0            1                  1                 4             2
# 1            1                  1                 2             2
# 2            1                  1                 6             2
# 3            1                  1                 7             2
# 4            1                  1                 3             2

# %%
X = features_base_model

y = ['revenue']

# %%
parameters = {'eval_metric': 'MAPE',
              'random_seed':42,
              'verbose':100}

# %%
model = CatBoostRegressor(**parameters)

# %%
df_model['invoice_date'].max()
# Out:
# Timestamp('2023-03-08 00:00:00')

# %%
start_forecast
# Out:
# '2023-03-08'

# %%
train_date = '2023-02-01'

# %% [markdown]
# ### First iteration

# %%
train_ = df[df['invoice_date']<train_date]
test_ = df[(df['invoice_date']>=train_date )&(df['invoice_date']<start_forecast )]

# %%
model.fit(train_[X],train_[y])
# Out:
# Learning rate set to 0.151935
# 0:	learn: 57.9329428	total: 629ms	remaining: 10m 28s
# 100:	learn: 57.8401998	total: 1m 6s	remaining: 9m 53s
# 200:	learn: 58.1122069	total: 2m 10s	remaining: 8m 39s
# 300:	learn: 58.4887015	total: 3m 14s	remaining: 7m 31s
# 400:	learn: 58.8982404	total: 4m 24s	remaining: 6m 34s
# 500:	learn: 59.2484527	total: 5m 25s	remaining: 5m 24s
# 600:	learn: 59.5923332	total: 6m 25s	remaining: 4m 16s
# 700:	learn: 59.8609910	total: 7m 24s	remaining: 3m 9s
# 800:	learn: 60.0693041	total: 8m 27s	remaining: 2m 6s
# 900:	learn: 60.3369294	total: 9m 27s	remaining: 1m 2s
# 999:	learn: 60.5652028	total: 10m 27s	remaining: 0us

# %%
model.predict(test_[X])
# Out:
# array([597.87793851, 184.95568743, 433.04386756, ...,  -9.26364378,
#         -3.45102448,  -3.00890458])

# %%
test_['predict_revenue']=model.predict(test_[X])

# %%
test_["predict_revenue"] = np.where((test_["predict_revenue"] < 0), 0, test_["predict_revenue"])

# %%
test_
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 182830   Female  (25.0, 30.0]   2023-02-01  Clothing    Credit Card
# 182831   Female  (25.0, 30.0]   2023-02-01  Clothing    Credit Card
# 182832   Female  (25.0, 30.0]   2023-02-01  Clothing    Credit Card
# 182833   Female  (25.0, 30.0]   2023-02-01  Clothing    Credit Card
# 182834   Female  (25.0, 30.0]   2023-02-01  Clothing    Credit Card
# ...         ...           ...          ...       ...            ...
# 5712592    Male  (40.0, 45.0]   2023-03-07  Souvenir           Cash
# 5712593    Male  (40.0, 45.0]   2023-03-07  Souvenir           Cash
# 5712594    Male  (40.0, 45.0]   2023-03-07  Souvenir           Cash
# 5712595    Male  (40.0, 45.0]   2023-03-07  Souvenir           Cash
# 5712596    Male  (40.0, 45.0]   2023-03-07  Souvenir           Cash
#
#              shopping_mall  revenue  year  day  month  weekday  weeknumber  \
# 182830              Kanyon    0.000  2023    1      2        2           5
# 182831      Forum Istanbul    0.000  2023    1      2        2           5
# 182832           Metrocity    0.000  2023    1      2        2           5
# 182833        Metropol AVM    0.000  2023    1      2        2           5
# 182834        Istinye Park 7502.000  2023    1      2        2           5
# ...                    ...      ...   ...  ...    ...      ...         ...
# 5712592   Mall of Istanbul    0.000  2023    7      3        1          10
# 5712593  Emaar Square Mall    0.000  2023    7      3        1          10
# 5712594        Cevahir AVM    0.000  2023    7      3        1          10
# 5712595     Viaport Outlet    0.000  2023    7      3        1          10
# 5712596       Zorlu Center    0.000  2023    7      3        1          10
#
#          is1jan  wn gender_ohe category_ohe payment_method_ohe  \
# 182830        0   1          0            1                  1
# 182831        0   1          0            1                  1
# 182832        0   1          0            1                  1
# 182833        0   1          0            1                  1
# 182834        0   1          0            1                  1
# ...         ...  ..        ...          ...                ...
# 5712592       0   1          1            5                  0
# 5712593       0   1          1            5                  0
# 5712594       0   1          1            5                  0
# 5712595       0   1          1            5                  0
# 5712596       0   1          1            5                  0
#
#         shopping_mall_ohe age_group_ohe  predict_revenue
# 182830                  4             2          597.878
# 182831                  2             2          184.956
# 182832                  6             2          433.044
# 182833                  7             2          288.954
# 182834                  3             2          327.073
# ...                   ...           ...              ...
# 5712592                 5             5            0.000
# 5712593                 1             5            0.000
# 5712594                 0             5            0.000
# 5712595                 8             5            0.000
# 5712596                 9             5            0.000
#
# [184937 rows x 20 columns]

# %% [markdown]
# ### Evaluate of error

# %%
def mean_absolute_error_day(y):
    y_piv = y.groupby(['invoice_date'])['predict_revenue', 'revenue'].sum().reset_index()
    y_piv['mae_revenue'] = np.abs(y_piv['predict_revenue'] - y_piv['revenue'])
    return np.mean(y_piv['mae_revenue'])/np.mean(y_piv['revenue'])

# %%
mean_absolute_error_day(test_)
# Out:
# 0.16101043056067738

# %% [markdown]
# Error - 16%

# %% [markdown]
# ### Full train data

# %%
df_model['invoice_date'].max()
# Out:
# Timestamp('2023-03-08 00:00:00')

# %%
start_forecast
# Out:
# '2023-03-08'

# %%
train = df[df['invoice_date']<=start_forecast]
df_predict= df[df['invoice_date']>start_forecast]

# %%
model.fit(train[X],train[y])
# Out:
# Learning rate set to 0.153049
# 0:	learn: 58.0895912	total: 661ms	remaining: 11m
# 100:	learn: 57.9309548	total: 1m	remaining: 9m 1s
# 200:	learn: 58.1415086	total: 1m 59s	remaining: 7m 53s
# 300:	learn: 58.5900989	total: 2m 58s	remaining: 6m 55s
# 400:	learn: 58.9626165	total: 3m 57s	remaining: 5m 54s
# 500:	learn: 59.2970326	total: 5m 3s	remaining: 5m 2s
# 600:	learn: 59.6202976	total: 6m 3s	remaining: 4m 1s
# 700:	learn: 59.8951767	total: 7m 4s	remaining: 3m
# 800:	learn: 60.1790677	total: 8m 4s	remaining: 2m
# 900:	learn: 60.4554980	total: 9m 2s	remaining: 59.6s
# 999:	learn: 60.6841262	total: 10m 3s	remaining: 0us

# %%
model.predict(df_predict[X])
# Out:
# array([553.07989826, 150.59662893, 430.81417718, ..., -11.86572815,
#        -13.75123474, -25.75886306])

# %%
df_predict['revenue']=model.predict(df_predict[X])

# %%
df_predict["revenue"] = np.where((df_predict["revenue"] < 0), 0, df_predict["revenue"])

# %%
df_predict
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 191480   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191481   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191482   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191483   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191484   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# ...         ...           ...          ...       ...            ...
# 5784352    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784353    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784354    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784355    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784356    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
#
#              shopping_mall  revenue  year  day  month  weekday  weeknumber  \
# 191480              Kanyon  553.080  2023    9      3        3          10
# 191481      Forum Istanbul  150.597  2023    9      3        3          10
# 191482           Metrocity  430.814  2023    9      3        3          10
# 191483        Metropol AVM  284.948  2023    9      3        3          10
# 191484        Istinye Park  285.615  2023    9      3        3          10
# ...                    ...      ...   ...  ...    ...      ...         ...
# 5784352   Mall of Istanbul   10.947  2023   31     12        6          52
# 5784353  Emaar Square Mall    9.754  2023   31     12        6          52
# 5784354        Cevahir AVM    0.000  2023   31     12        6          52
# 5784355     Viaport Outlet    0.000  2023   31     12        6          52
# 5784356       Zorlu Center    0.000  2023   31     12        6          52
#
#          is1jan  wn gender_ohe category_ohe payment_method_ohe  \
# 191480        0   1          0            1                  1
# 191481        0   1          0            1                  1
# 191482        0   1          0            1                  1
# 191483        0   1          0            1                  1
# 191484        0   1          0            1                  1
# ...         ...  ..        ...          ...                ...
# 5784352       0   0          1            5                  0
# 5784353       0   0          1            5                  0
# 5784354       0   0          1            5                  0
# 5784355       0   0          1            5                  0
# 5784356       0   0          1            5                  0
#
#         shopping_mall_ohe age_group_ohe
# 191480                  4             2
# 191481                  2             2
# 191482                  6             2
# 191483                  7             2
# 191484                  3             2
# ...                   ...           ...
# 5784352                 5             5
# 5784353                 1             5
# 5784354                 0             5
# 5784355                 8             5
# 5784356                 9             5
#
# [1573440 rows x 19 columns]

# %%
df_predict_base = [train,df_predict]

df_predict_base = pd.concat(df_predict_base)

df_predict_base_revenue_per_year = df_predict_base.groupby('year')['revenue'].sum().reset_index()
df_predict_base_revenue_per_year
#train_test_revenue_per_year
#df['lagged_values'] = df.groupby(['group'])['values'].shift(1)
# Out:
#    year       revenue
# 0  2021 114560570.590
# 1  2022 115436814.080
# 2  2023 118987438.270

# %% [markdown]
# ## Lets create the final dataset with predicted values

# %%
df_predict.columns
# Out:
# Index(['gender', 'age_group', 'invoice_date', 'category', 'payment_method',
#        'shopping_mall', 'revenue', 'year', 'day', 'month', 'weekday',
#        'weeknumber', 'is1jan', 'wn', 'gender_ohe', 'category_ohe',
#        'payment_method_ohe', 'shopping_mall_ohe', 'age_group_ohe'],
#       dtype='object')

# %%
df_predict_share = (df_predict[['gender', 'age_group', 'invoice_date', 'category', 'payment_method',
       'shopping_mall', 'revenue']])

df_predict_share = (df_predict_share[df_predict_share['revenue'] != 0 ])

df_predict_share
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 191480   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191481   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191482   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191483   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191484   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# ...         ...           ...          ...       ...            ...
# 5784347    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784348    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784351    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784352    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784353    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
#
#              shopping_mall  revenue
# 191480              Kanyon  553.080
# 191481      Forum Istanbul  150.597
# 191482           Metrocity  430.814
# 191483        Metropol AVM  284.948
# 191484        Istinye Park  285.615
# ...                    ...      ...
# 5784347             Kanyon   18.969
# 5784348     Forum Istanbul   16.776
# 5784351       Istinye Park   26.701
# 5784352   Mall of Istanbul   10.947
# 5784353  Emaar Square Mall    9.754
#
# [1192210 rows x 7 columns]

# %%
df_predict_share['month_year'] =  df_predict_share['invoice_date'].dt.strftime('%Y-%m-01')
df_predict_share['month_year'] = pd.to_datetime(df_predict_share['month_year'], format='%Y-%m-%d')

# %%
df_predict_share
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 191480   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191481   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191482   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191483   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# 191484   Female  (25.0, 30.0]   2023-03-09  Clothing    Credit Card
# ...         ...           ...          ...       ...            ...
# 5784347    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784348    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784351    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784352    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784353    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
#
#              shopping_mall  revenue month_year
# 191480              Kanyon  553.080 2023-03-01
# 191481      Forum Istanbul  150.597 2023-03-01
# 191482           Metrocity  430.814 2023-03-01
# 191483        Metropol AVM  284.948 2023-03-01
# 191484        Istinye Park  285.615 2023-03-01
# ...                    ...      ...        ...
# 5784347             Kanyon   18.969 2023-12-01
# 5784348     Forum Istanbul   16.776 2023-12-01
# 5784351       Istinye Park   26.701 2023-12-01
# 5784352   Mall of Istanbul   10.947 2023-12-01
# 5784353  Emaar Square Mall    9.754 2023-12-01
#
# [1192210 rows x 8 columns]

# %%
df_predict_share.to_csv('df_predict.csv')

# %%
df_model['month_year'] =  df_model['invoice_date'].dt.strftime('%Y-%m-01')
df_model['month_year'] = pd.to_datetime(df_model['month_year'], format='%Y-%m-%d')

# %%
df_model = df_model[['gender','age_group','invoice_date','category','payment_method','shopping_mall','revenue','month_year']]

# %%
df_model
# Out:
#        gender     age_group invoice_date         category payment_method  \
# 0      Female  (25.0, 30.0]   2022-08-05         Clothing    Credit Card
# 1        Male  (20.0, 25.0]   2021-12-12            Shoes     Debit Card
# 2        Male  (15.0, 20.0]   2021-11-09         Clothing           Cash
# 3      Female   (65.0, inf]   2021-05-16            Shoes    Credit Card
# 4      Female  (50.0, 55.0]   2021-10-24            Books           Cash
# ...       ...           ...          ...              ...            ...
# 99452  Female  (40.0, 45.0]   2022-09-21         Souvenir    Credit Card
# 99453    Male  (25.0, 30.0]   2021-09-22  Food & Beverage           Cash
# 99454    Male  (60.0, 65.0]   2021-03-28  Food & Beverage     Debit Card
# 99455    Male  (55.0, 60.0]   2021-03-16       Technology           Cash
# 99456  Female  (35.0, 40.0]   2022-10-15         Souvenir    Credit Card
#
#           shopping_mall   revenue month_year
# 0                Kanyon  7502.000 2022-08-01
# 1        Forum Istanbul  5401.530 2021-12-01
# 2             Metrocity   300.080 2021-11-01
# 3          Metropol AVM 15004.250 2021-05-01
# 4                Kanyon   242.400 2021-10-01
# ...                 ...       ...        ...
# 99452            Kanyon   293.250 2022-09-01
# 99453    Forum Istanbul    20.920 2021-09-01
# 99454         Metrocity    20.920 2021-03-01
# 99455      Istinye Park 16800.000 2021-03-01
# 99456  Mall of Istanbul   105.570 2022-10-01
#
# [99457 rows x 8 columns]

# %%
df_model.to_csv('df_base.csv')

# %%
df_full_data = [df_model,df_predict_share]
df_full_data = pd.concat(df_full_data)
df_full_data
# Out:
#          gender     age_group invoice_date  category payment_method  \
# 0        Female  (25.0, 30.0]   2022-08-05  Clothing    Credit Card
# 1          Male  (20.0, 25.0]   2021-12-12     Shoes     Debit Card
# 2          Male  (15.0, 20.0]   2021-11-09  Clothing           Cash
# 3        Female   (65.0, inf]   2021-05-16     Shoes    Credit Card
# 4        Female  (50.0, 55.0]   2021-10-24     Books           Cash
# ...         ...           ...          ...       ...            ...
# 5784347    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784348    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784351    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784352    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
# 5784353    Male  (40.0, 45.0]   2023-12-31  Souvenir           Cash
#
#              shopping_mall   revenue month_year
# 0                   Kanyon  7502.000 2022-08-01
# 1           Forum Istanbul  5401.530 2021-12-01
# 2                Metrocity   300.080 2021-11-01
# 3             Metropol AVM 15004.250 2021-05-01
# 4                   Kanyon   242.400 2021-10-01
# ...                    ...       ...        ...
# 5784347             Kanyon    18.969 2023-12-01
# 5784348     Forum Istanbul    16.776 2023-12-01
# 5784351       Istinye Park    26.701 2023-12-01
# 5784352   Mall of Istanbul    10.947 2023-12-01
# 5784353  Emaar Square Mall     9.754 2023-12-01
#
# [1291667 rows x 8 columns]

# %%
df_full_data.to_csv('df_full_data.csv')
